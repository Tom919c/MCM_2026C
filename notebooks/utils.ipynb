# %%
import pickle
path = r"D:/Code/VSCode/MCM_2026C/data/processed\datas.pkl"
with open(path,'rb') as f:
    datas = pickle.load(f)
print(datas.keys())
# Out:
# dict_keys(['raw_data', 'features', 'celebrity_participation_stats', 'partner_participation_stats', 'missing_judge4_weeks', 'long_data', 'pro_id_map', 'train_data', 'index_maps', 'standardization_params'])

# %%
tf = datas['train_data']
print(tf.keys())
# Out:
# dict_keys(['n_obs', 'n_weeks', 'n_celebs', 'n_pros', 'n_seasons', 'celeb_idx', 'pro_idx', 'week_idx', 'season_idx', 'X_celeb', 'X_pro', 'X_obs', 'X_celeb_names', 'X_pro_names', 'X_obs_names', 'judge_score_pct', 'judge_rank_score', 'week_data'])

# %%
print(tf["X_pro_names"])
# Out:
# []
