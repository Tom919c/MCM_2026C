# %%
import sys
from pathlib import Path

# %%
project_root = Path(__file__).parent.parent
sys.path.insert(0, str(project_root))

from src.data_manager import load_data, save_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 project_root = Path(__file__).parent.parent
#       2 sys.path.insert(0, str(project_root))
#       4 from src.data_manager import load_data, save_data
#
# NameError: name '__file__' is not defined

# %%
import pickle
import numpy as np
path = r"D:\Code\VSCode\MCM_2026C\data\processed\datas.pkl"
with open(path,'rb') as f:
    datas = pickle.load(f)
# print(datas.keys())
tf = datas['train_data']
print(tf.keys())
tf1 = tf['week_data']
# Out:
# dict_keys(['n_obs', 'n_weeks', 'n_celebs', 'n_pros', 'n_seasons', 'celeb_idx', 'pro_idx', 'week_idx', 'season_idx', 'X_celeb', 'X_pro', 'X_obs', 'X_celeb_names', 'X_pro_names', 'X_obs_names', 'judge_score_pct', 'judge_rank_score', 'week_data'])

# %%
# print(tf["X_obs"])
print(tf['X_obs_names'])
# Out:
# ['same_sex_pair', 'pro_prev_wins', 'pro_avg_rank', 'judge_score_raw', 'z_score', 'score_trend', 'is_top_score', 'perfect_score', 'judge_score_stddev', 'judge_rank', 'times_in_bottom', 'cumulative_avg_score', 'teflon_factor', 'weeks_survived', 'season_era', 'voting_rule_type', 'judge_save_active', 'elimination_count', 'result_status']
